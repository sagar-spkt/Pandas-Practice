# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv("weather_data.csv")
df1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>temperature</th>
#       <th>windspeed</th>
#       <th>event</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1/1/2017</td>
#       <td>32</td>
#       <td>6</td>
#       <td>Rain</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1/2/2017</td>
#       <td>35</td>
#       <td>7</td>
#       <td>Sunny</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1/3/2017</td>
#       <td>28</td>
#       <td>2</td>
#       <td>Snow</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1/4/2017</td>
#       <td>24</td>
#       <td>7</td>
# ...

# %% [markdown]
# From dictionary

# %%
weather_data = {
    'day': ['1/1/2017', '1/2/2017', '1/3/2017', '1/4/2017', '1/5/2017', '1/6/2017'],
    'temperature': [32, 35, 28, 24, 32, 31],
    'windspeed': [6, 7, 2, 7, 4, 2],
    'event': ['Rain', 'Sunny', 'Snow', 'Snow', 'Rain', 'Sunny']
}
df2 = pd.DataFrame(weather_data)
df2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>temperature</th>
#       <th>windspeed</th>
#       <th>event</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1/1/2017</td>
#       <td>32</td>
#       <td>6</td>
#       <td>Rain</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1/2/2017</td>
#       <td>35</td>
#       <td>7</td>
#       <td>Sunny</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1/3/2017</td>
#       <td>28</td>
#       <td>2</td>
#       <td>Snow</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1/4/2017</td>
#       <td>24</td>
#       <td>7</td>
# ...

# %%
df3 = pd.DataFrame({
    'one': pd.Series(np.random.randn(3), index=['a', 'b', 'c', ]),
    'two': pd.Series(np.random.randn(4), index=['a', 'b', 'c', 'd', ]),
    'three': pd.Series(np.random.randn(3), index=['b', 'c', 'd']),
})
df3
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>one</th>
#       <th>two</th>
#       <th>three</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>-0.095417</td>
#       <td>-0.863655</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>-1.826869</td>
#       <td>-1.009929</td>
#       <td>-0.147885</td>
#     </tr>
#     <tr>
#       <th>c</th>
#       <td>-0.447902</td>
#       <td>-1.861574</td>
#       <td>-0.449261</td>
#     </tr>
#     <tr>
#       <th>d</th>
#       <td>NaN</td>
#       <td>0.187522</td>
#       <td>0.071982</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Shape

# %%
df1.shape
# Out:
# (6, 4)

# %%
df2.shape
# Out:
# (6, 4)

# %% [markdown]
# datarame head: few first rows

# %%
df1.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>temperature</th>
#       <th>windspeed</th>
#       <th>event</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1/1/2017</td>
#       <td>32</td>
#       <td>6</td>
#       <td>Rain</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1/2/2017</td>
#       <td>35</td>
#       <td>7</td>
#       <td>Sunny</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1/3/2017</td>
#       <td>28</td>
#       <td>2</td>
#       <td>Snow</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1/4/2017</td>
#       <td>24</td>
#       <td>7</td>
# ...

# %%
df2.head(2)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>temperature</th>
#       <th>windspeed</th>
#       <th>event</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1/1/2017</td>
#       <td>32</td>
#       <td>6</td>
#       <td>Rain</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1/2/2017</td>
#       <td>35</td>
#       <td>7</td>
#       <td>Sunny</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# dataframe tail

# %%
df2.tail()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>temperature</th>
#       <th>windspeed</th>
#       <th>event</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>1/2/2017</td>
#       <td>35</td>
#       <td>7</td>
#       <td>Sunny</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1/3/2017</td>
#       <td>28</td>
#       <td>2</td>
#       <td>Snow</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1/4/2017</td>
#       <td>24</td>
#       <td>7</td>
#       <td>Snow</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1/5/2017</td>
#       <td>32</td>
#       <td>4</td>
# ...

# %%
df1.tail(2)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>temperature</th>
#       <th>windspeed</th>
#       <th>event</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4</th>
#       <td>1/5/2017</td>
#       <td>32</td>
#       <td>4</td>
#       <td>Rain</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1/6/2017</td>
#       <td>31</td>
#       <td>2</td>
#       <td>Sunny</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Indexing and slicing

# %%
df1[2:5]  # print everything df1[:]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>temperature</th>
#       <th>windspeed</th>
#       <th>event</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>1/3/2017</td>
#       <td>28</td>
#       <td>2</td>
#       <td>Snow</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1/4/2017</td>
#       <td>24</td>
#       <td>7</td>
#       <td>Snow</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1/5/2017</td>
#       <td>32</td>
#       <td>4</td>
#       <td>Rain</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Data frame Columns

# %%
df1.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df1.event
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# Name: event, dtype: object

# %%
df1['event']
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# Name: event, dtype: object

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df1['event'])
# Out:
# pandas.core.series.Series

# %%
df1[['day', 'temperature']]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>temperature</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1/1/2017</td>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1/2/2017</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1/3/2017</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1/4/2017</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1/5/2017</td>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1/6/2017</td>
#       <td>31</td>
#     </tr>
#   </tbody>
# ...

# %%
df1[1:2]  # not df1[1]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>temperature</th>
#       <th>windspeed</th>
#       <th>event</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>1/2/2017</td>
#       <td>35</td>
#       <td>7</td>
#       <td>Sunny</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df1.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>temperature</th>
#       <th>windspeed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>6.000000</td>
#       <td>6.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>30.333333</td>
#       <td>4.666667</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>3.829708</td>
#       <td>2.338090</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>24.000000</td>
#       <td>2.000000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>28.750000</td>
#       <td>2.500000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
# ...

# %% [markdown]
# Conditional selector like SQL

# %%
df1[df1.temperature >= 32]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>temperature</th>
#       <th>windspeed</th>
#       <th>event</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1/1/2017</td>
#       <td>32</td>
#       <td>6</td>
#       <td>Rain</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1/2/2017</td>
#       <td>35</td>
#       <td>7</td>
#       <td>Sunny</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1/5/2017</td>
#       <td>32</td>
#       <td>4</td>
#       <td>Rain</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# DataFrame with max temperature

# %%
df1[df1.temperature == df1.temperature.max()]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>temperature</th>
#       <th>windspeed</th>
#       <th>event</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>1/2/2017</td>
#       <td>35</td>
#       <td>7</td>
#       <td>Sunny</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df1[df1.temperature == df1.temperature.max()]['day']
# Out:
# 1    1/2/2017
# Name: day, dtype: object

# %%
df1[['day', 'temperature']][df1.temperature == df1.temperature.max()]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>temperature</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>1/2/2017</td>
#       <td>35</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
row = df3.iloc[1]
row
# Out:
# one     -1.826869
# two     -1.009929
# three   -0.147885
# Name: b, dtype: float64

# %%
type(row)
# Out:
# pandas.core.series.Series

# %% [markdown]
# index operation

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %% [markdown]
# without inplace=True set_index method doesn't change original dataframe instead return new dataframe with given index

# %%
df1.set_index('day', inplace=True)
df1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>temperature</th>
#       <th>windspeed</th>
#       <th>event</th>
#     </tr>
#     <tr>
#       <th>day</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1/1/2017</th>
#       <td>32</td>
#       <td>6</td>
#       <td>Rain</td>
#     </tr>
#     <tr>
#       <th>1/2/2017</th>
#       <td>35</td>
#       <td>7</td>
#       <td>Sunny</td>
#     </tr>
#     <tr>
#       <th>1/3/2017</th>
#       <td>28</td>
#       <td>2</td>
#       <td>Snow</td>
#     </tr>
#     <tr>
#       <th>1/4/2017</th>
#       <td>24</td>
#       <td>7</td>
# ...

# %%
df1.index
# Out:
# Index(['1/1/2017', '1/2/2017', '1/3/2017', '1/4/2017', '1/5/2017', '1/6/2017'], dtype='object', name='day')

# %%
df1.loc['1/1/2017']
# Out:
# temperature      32
# windspeed         6
# event          Rain
# Name: 1/1/2017, dtype: object

# %%
df1.reset_index(inplace=True)

# %%
df1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>day</th>
#       <th>temperature</th>
#       <th>windspeed</th>
#       <th>event</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1/1/2017</td>
#       <td>32</td>
#       <td>6</td>
#       <td>Rain</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>1/2/2017</td>
#       <td>35</td>
#       <td>7</td>
#       <td>Sunny</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>1/3/2017</td>
#       <td>28</td>
#       <td>2</td>
#       <td>Snow</td>
#     </tr>
#     <tr>
# ...
